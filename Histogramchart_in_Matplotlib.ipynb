# %% [markdown]
# # Histogram

# %%
import matplotlib.pyplot as plt 
import numpy as np
import random

x=np.random.randint(10,60,(50))
print(x)
# Out:
# [48 11 52 43 59 34 31 30 37 32 33 23 27 53 21 39 22 32 13 18 35 52 38 18
#  25 34 55 50 42 53 44 59 45 33 46 21 18 14 29 26 43 58 49 43 11 40 42 29
#  17 25]

# %%
no=[33,46,46,12,30,55,23,53,24,40,33,24,42,11,27,35,58,12,37,47,31,39,20,29,37,12,58,50,10,59,47,13,40,55,54,43,48,53,34,40,30,54,55,30,17,
 34,35]
l=[10,20,30,40,50,60]
plt.hist(no,"auto",(0,100),edgecolor="r")

plt.title("Boxplot")
plt.xlabel("Python")
plt.ylabel("No")
plt.show()

# %%
no=[33,46,46,12,30,55,23,53,24,40,33,24,42,11,27,35,58,12,37,47,31,39,20,29,37,12,58,50,10,59,47,13,40,55,54,43,48,53,34,40,30,54,55,30,17,
 34,35]
l=[10,20,30,40,50,60]
plt.hist(no,color="b",edgecolor="r",cumulative=-1)

plt.title("Boxplot")
plt.xlabel("Python")
plt.ylabel("No")
plt.show()

# %%
no=[33,46,46,12,30,55,23,53,24,40,33,24,42,11,27,35,58,12,37,47,31,39,20,29,37,12,58,50,10,59,47,13,40,55,54,43,48,53,34,40,30,54,55,30,17,
 34,35]
l=[10,20,30,40,50,60]
plt.hist(no,color="b",edgecolor="r",bottom=10)

plt.title("Boxplot")
plt.xlabel("Python")
plt.ylabel("No")
plt.show()

# %%
no=[33,46,46,12,30,55,23,53,24,40,33,24,42,11,27,35,58,12,37,47,31,39,20,29,37,12,58,50,10,59,47,13,40,55,54,43,48,53,34,40,30,54,55,30,17,
 34,35]
l=[10,20,30,40,50,60]
plt.hist(no,color="b",edgecolor="r",histtype="step")

plt.title("Boxplot")
plt.xlabel("Python")
plt.ylabel("No")
plt.show()

# %%
no=[33,46,46,12,30,55,23,53,24,40,33,24,42,11,27,35,58,12,37,47,31,39,20,29,37,12,58,50,10,59,47,13,40,55,54,43,48,53,34,40,30,54,55,30,17,
 34,35]
l=[10,20,30,40,50,60]
plt.hist(no,color="b",edgecolor="r",orientation="horizontal")

plt.title("Boxplot")
plt.xlabel("Python")
plt.ylabel("No")
plt.show()

# %%
no=[33,46,46,12,30,55,23,53,24,40,33,24,42,11,27,35,58,12,37,47,31,39,20,29,37,12,58,50,10,59,47,13,40,55,54,43,48,53,34,40,30,54,55,30,17,
 34,35]
l=[10,20,30,40,50,60]
plt.hist(no,color="b",edgecolor="r",log=True)

plt.title("Boxplot")
plt.xlabel("Python")
plt.ylabel("No")
plt.show()

# %%
no=[33,46,46,12,30,55,23,53,24,40,33,24,42,11,27,35,58,12,37,47,31,39,20,29,37,12,58,50,10,59,47,13,40,55,54,43,48,53,34,40,30,54,55,30,17,
 34,35]
l=[10,20,30,40,50,60]
plt.hist(no,edgecolor="r",label="python")

plt.title("Boxplot")
plt.xlabel("Python")
plt.ylabel("No")

plt.axvline(45,color="g",label="line")

plt.legend()
plt.grid()
plt.show()
