# %% [markdown]
# # Stack Plot

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
area = [2,1,3,4,2]
area1 = [2,1,3,4,2]
area2 = [2,1,3,4,2]

l=["area","area1","area2"]
plt.stackplot(x,area,area1,area2,labels=l,colors=["r","m","b"],baseline="sym")

plt.title("Python")
plt.legend(loc=2)
plt.show()
